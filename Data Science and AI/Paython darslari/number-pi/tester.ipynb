# %%
file = open("number_pi.txt",'r').read()

def split_string_by_2_characters(input_string):
    return [input_string[i:i+2] for i in range(0, len(input_string), 2)]

sliced = split_string_by_2_characters(file)

i = 0
while i < len(sliced):
    sliced[i] = chr(int(sliced[i]))
    i += 1

    

print(sliced)

file = '123456789'

def split_string_by_2_characters(input_string):
    return [input_string[i:i+2] for i in range(0, len(input_string), 2)]

sliced = split_string_by_2_characters(file)

with open('pi2char.txt','a+') as file:
    for character in sliced:
        file.write(chr(int(sliced[i])))
# Out:
# ['<', '!', ' ', 'c', '\x0b', ')', '\x01', 'a', '\x0b', '=', '\x01', '\n', '\x03', '\x1d', 'Q', '\x15', ' ', 'M', '\n', ';', '[', '\x04', 'a', '\n', '\x0b', '\x08', ' ', 'D', '.', ' ', 'H', '\x0b', 'O', 'Q', '\x01', '\x0b', ')', '\x10', '\x0c', '\x0e', '+', '\x1b', '3', '\x0b', ' ', 'H', 'a', '\x0c', '\x13', 'G', '\x0f', '\n', ')', '\x05', ' ', '&', ' ', 'C', '\n', ')', '\x05', 'a', ' ', 'V', 'a', '\x0b', '\x01', '\x03', ' ', '3', '/', '9', '6', '>', '\n', '<', '!', ' ', 'C', '\x0b', '\x0b', '\x0c', '\x0c', '\x0b', '\x0e', '\n', '3', '\x03', '\n', ')', '\x10', ' ', '1', '9', '9', '9', '-', '1', '9', '9', '7', ' ', 'M', '\n', ';', '[', '\x04', 'a', '\n', '\x0b', '\x08', ' ', 'D', '.', ' ', 'H', '\x0b', 'O', 'Q', '\x01', '\x0b', ')', '\x10', '\x0c', '\x0e', '+', '\x1b', '3', '\x0b', ' ', 'H', 'a', '\x0c', '\x13', 'G', '\x0f', '\n', ')', '\x05', ' ', '&', ' ', 'C', '\n', ')', '\x05', 'a', ' ', '\n', 'V', 'a', '\x0b', '\x01', '\x03', '.', ' ', ' ', '\n', 'A', '\n', 'Q', '\x08', ' ', '\x0b', ')', '\x05', '\n', '\x1f', '\x04', '\x0b', '=', '\x0f', ' ', '\x0b', ')', '\x01', '\x0b', '3', '\x01', '\x0b', ')', '\x12', '\n', '\x0b', '\x00', '.', '>', '\n', '\n', '<', '\n', ')', '\x10', '\n', '[', '\x08', '>', '<', '\n', ')', '\x01', 'a', '\n', '\x06', '\x15', '\x06', '\x01', '\x10', '\n', '3', '\x10', '\n', 'Q', '\x01', '>', '1', '0', '0', ',', '0', '0', '0', ' ', 'D', '\n', '3', '\x03', '\n', '3', '\x10', '\x0b', '5', '\x15', '\x0b', '\n', '\x17', '\x1c', '\x01', '\x05', '<', '/', '\x0b', '=', '\x05', '\x0b', '=', '\x08', '\n', '\x10', '\x15', '\x06', '\x04', 'G', '\x04', '\n', '\x13', 'G', '\x00', '>', '\n', ' ', ' ', ' ', '\n', '<', 'b', '\x0b', '\x0b', '\x00', '\x0c', '\x10', '\x15', '\x06', '\t', '[', '\x01', '\x0b', '\x01', '\x10', '\n', '\x0b', '\x0e', '>', '<', '\n', ',', '`', '\x18', '^', 'T', 'T', ',', 'T', 'T', 'S', '\x1a', 'Q', '\x05', '\n', '\x1f', '\x05', '\x0b', '=', '\x0f', ' ', '\x0b', '\x0b', '\x02', ' ', 'P', '\n', '8', '\x01', '\x05', '\n', '[', '\x03', ' ', '\x0b', '3', '\x0e', 'c', '=', '"', '\x0b', '\x15', '\x05', '\n', 'Q', '\x0b', '\n', '\x1f', '\x0b', '.', '\n', '\x1f', '\x05', '\n', '\x17', '+', '\x1d', 'G', '\x08', '\x0b', 'B', '\r', '0', '\x01', '\x05', ' ', 'L', '\x0b', '\x0b', '\x03', '\x0b', '\r', '+', '\x1d', 'G', '\x08', '\n', '3', '\x03', '\x0b', '\x06', '\x0b', '\t', '\n', '3', '\x00', '\n', '\x01', '\x08', '\n', '\x10', '\x1a', '\x04', 'G', '\x04', '1', '>', '<', '/', 'c', '\n', '\x0b', '\n', '\x0b', '=', '\x01', '\x0b', '.', '\x15', '\x06', '\t', 'Q', '\x0e', '>', '\n', ' ', '3', '.', '1', '4', '1', '5', '9', '2', '6', '5', '3', '5', '8', '9', '7', '9', '3', '2', '3', '8', '4', '6', '2', '6', '4', '3', '3', '8', '3', '2', '7', '9', '5', '0', '2', '8', '8', '4', '1', '9', '7', '1', '6', '9', '3', '9', '9', '3', '7', '5', '1', '0', '5', '8', '2', '0', '9', '7', '4', '9', '4', '4', '5', '9', '2', '3', '0', '7', '8', '1', '6', '4', '0', '6', '2', '8', '6', '\n', '2', '0', '8', '9', '9', '8', '6', '2', '8', '0', '3', '4', '8', '2', '5', '3', '4', '2', '1', '1', '7', '0', '6', '7', '9', '8', '2', '1', '4', '8', '0', '8', '6', '5', '1', '3', '2', '8', '2', '3', '0', '6', '6', '4', '7', '0', '9', '3', '8', '4', '4', '6', '0', '9', '5', '5', '0', '5', '8', '2', '2', '3', '1', '7', '2', '5', '3', '5', '9', '4', '0', '8', '1', '2', '8', '4', '8', '1', '\n', '1', '1', '7', '4', '5', '0', '2', '8', '4', '1', '0', '2', '7', '0', '1', '9', '3', '8', '5', '2', '1', '1', '0', '5', '5', '5', '9', '6', '4', '4', '6', '2', '2', '9', '4', '8', '9', '5', '4', '9', '3', '0', '3', '8', '1', '9', '6', '4', '4', '2', '8', '8', '1', '0', '9', '7', '5', '6', '6', '5', '9', '3', '3', '4', '4', '6', '1', '2', '8', '4', '7', '5', '6', '4', '8', '2', '3', '3', '\n', '7', '8', '6', '7', '8', '3', '1', '6', '5', '2', '7', '1', '2', '0', '1', '9', '0', '9', '1', '4', '5', '6', '4', '8', '5', '6', '6', '9', '2', '3', '4', '6', '0', '3', '4', '8', '6', '1', '0', '4', '5', '4', '3', '2', '6', '6', '4', '8', '2', '1', '3', '3', '9', '3', ' ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\mohirdev\Data Science and AI\Paython darslari\number-pi\tester.ipynb Cell 1 in 2
#      <a href='vscode-notebook-cell:/d%3A/mohirdev/Data%20Science%20and%20AI/Paython%20darslari/number-pi/tester.ipynb#W3sZmlsZQ%3D%3D?line=23'>24</a> with open('pi2char.txt','a+') as file:
#      <a href='vscode-notebook-cell:/d%3A/mohirdev/Data%20Science%20and%20AI/Paython%20darslari/number-pi/tester.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a>     for character in sliced:
# ---> <a href='vscode-notebook-cell:/d%3A/mohirdev/Data%20Science%20and%20AI/Paython%20darslari/number-pi/tester.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a>         file.write(chr(int(sliced[i])))
#
# IndexError: list index out of range
