# %% [markdown]
# <a href="https://colab.research.google.com/github/KamronbekSolih/mohirdev/blob/main/pd_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# KEling keyingi mashqlar uchun Githubdan kattaroq DF yuklab olamiz
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/usa_cars.csv', index_col=0)
df.head()
# Out:
#    price      brand    model  year   title_status  mileage   color  \
# 0   6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1   2899       ford       se  2011  clean vehicle   190552  silver
# 2   5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3  25000       ford     door  2014  clean vehicle    64146    blue
# 4  27700  chevrolet     1500  2018  clean vehicle     6654     red
#
#                    vin        lot       state country      condition
# 0    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
models = df['model'].unique()
models.sort()
models
# Out:
# array(['1500', '2500', '2500hd', '300', '3500', '5', 'acadia', 'altima',
#        'armada', 'bus', 'cab', 'camaro', 'caravan', 'cargo', 'challenger',
#        'charger', 'chassis', 'cherokee', 'colorado', 'compass', 'connect',
#        'convertible', 'corvette', 'country', 'coupe', 'cruiser', 'cruze',
#        'cutaway', 'cx-3', 'd', 'dart', 'discovery', 'door', 'doors', 'dr',
#        'drw', 'durango', 'e-class', 'ecosport', 'edge', 'el', 'elantra',
#        'enclave', 'encore', 'energi', 'equinox', 'escape', 'esv',
#        'expedition', 'explorer', 'f-150', 'f-650', 'f-750', 'fiesta',
#        'flex', 'focus', 'forte', 'frontier', 'fusion', 'ghibli', 'glc',
#        'gle', 'gx', 'hybrid', 'impala', 'journey', 'juke', 'kicks', 'ld',
#        'limited', 'm', 'malibu', 'max', 'maxima', 'mdx', 'mpv', 'murano',
#        'mustang', 'nautilus', 'note', 'nvp', 'pacifica', 'passenger',
#        'pathfinder', 'pickup', 'pioneer', 'pk', 'q5', 'q70', 'ranger',
# ...

# %%
df['color'].value_counts()
# Out:
# white                                      707
# black                                      516
# gray                                       395
# silver                                     300
# red                                        192
# blue                                       151
# no_color                                    61
# green                                       24
# orange                                      20
# gold                                        19
# charcoal                                    18
# brown                                       15
# yellow                                       9
# magnetic metallic                            6
# shadow black                                 5
# color:                                       5
# beige                                        5
# oxford white                                 4
# ingot silver metallic                        4
# super black                                  3
# ...

# %%
models.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c4a543a827db> in <cell line: 1>()
# ----> 1 models.value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
df['model'].value_counts()
# Out:
# door        651
# f-150       219
# doors       148
# caravan     102
# mpv          87
#            ...
# sl-class      1
# cx-3          1
# 2500hd        1
# mdx           1
# nvp           1
# Name: model, Length: 127, dtype: int64

# %%
df['title_status'].value_counts().values
# Out:
# array([2336,  163])

# %%
import matplotlib.pyplot as plt

# %%
sizes = df['title_status'].value_counts().values
labels = df['title_status'].value_counts().index
sizes
# Out:
# array([2336,  163])

# %%
labels
# Out:
# Index(['clean vehicle', 'salvage insurance'], dtype='object')

# %%
# Create a pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=140)

# Set aspect ratio to make the pie chart a circle
plt.axis('equal')

# Display the pie chart
plt.show()

# %%
df
# Out:
#       price      brand    model  year   title_status  mileage   color  \
# 0      6300     toyota  cruiser  2008  clean vehicle   274117   black
# 1      2899       ford       se  2011  clean vehicle   190552  silver
# 2      5350      dodge      mpv  2018  clean vehicle    39590  silver
# 3     25000       ford     door  2014  clean vehicle    64146    blue
# 4     27700  chevrolet     1500  2018  clean vehicle     6654     red
# ...     ...        ...      ...   ...            ...      ...     ...
# 2494   7800     nissan    versa  2019  clean vehicle    23609     red
# 2495   9200     nissan    versa  2018  clean vehicle    34553  silver
# 2496   9200     nissan    versa  2018  clean vehicle    31594  silver
# 2497   9200     nissan    versa  2018  clean vehicle    32557   black
# 2498   9200     nissan    versa  2018  clean vehicle    31371  silver
#
#                       vin        lot       state country      condition
# ...

# %%
df['country']
# Out:
# 0        usa
# 1        usa
# 2        usa
# 3        usa
# 4        usa
#         ...
# 2494     usa
# 2495     usa
# 2496     usa
# 2497     usa
# 2498     usa
# Name: country, Length: 2499, dtype: object

# %%
df['country'].value_counts()
# Out:
#  usa       2492
#  canada       7
# Name: country, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# ford               1235
# dodge               432
# nissan              312
# chevrolet           297
# gmc                  42
# jeep                 30
# chrysler             18
# bmw                  17
# hyundai              15
# kia                  13
# buick                13
# infiniti             12
# honda                12
# cadillac             10
# mercedes-benz        10
# heartland             5
# land                  4
# peterbilt             4
# audi                  4
# acura                 3
# lincoln               2
# lexus                 2
# mazda                 2
# maserati              1
# toyota                1
# harley-davidson       1
# jaguar                1
# ram                   1
# Name: brand, dtype: int64

# %%
k_brands = ['hyundai','kia']
k_brands.isin(df['brand'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-6907ccca8a21> in <cell line: 2>()
#       1 k_brands = ['hyundai','kia']
# ----> 2 k_brands.isin(df['brand'])
#
# AttributeError: 'list' object has no attribute 'isin'

# %%
df['brand'].isin(k_brands)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2494    False
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# Name: brand, Length: 2499, dtype: bool

# %%
filter = df['brand'].isin(k_brands)

# %%
df[filter].sort_values(by=['brand','price'],ascending=False)
# Out:
#      price    brand     model  year       title_status  mileage  \
# 26   21500      kia   sorento  2020      clean vehicle    11451
# 631  21500      kia   sorento  2017      clean vehicle    43761
# 629  15500      kia   sorento  2017      clean vehicle    37668
# 623  14000      kia   sorento  2017      clean vehicle    53424
# 292  13800      kia   sorento  2017      clean vehicle    86959
# 626  13300      kia      door  2017      clean vehicle    37125
# 440  13000      kia  sportage  2017      clean vehicle    71991
# 291  12700      kia      soul  2019      clean vehicle    23514
# 21    7300      kia     forte  2018      clean vehicle    38823
# 16    5200      kia     forte  2018      clean vehicle    46194
# 527   3810      kia      door  2016      clean vehicle    39408
# 288   3000      kia      door  2013      clean vehicle    97142
# 419      0      kia     wagon  2008  salvage insurance   148463
# 296   9800  hyundai   elantra  2017      clean vehicle    35687
# ...

# %%
filter2 = df['price']>70000

# %%
df[filter2]
# Out:
#       price          brand     model  year   title_status  mileage     color  \
# 502   84900  mercedes-benz  sl-class  2017  clean vehicle    25302    silver
# 1340  74000           ford       drw  2019  clean vehicle    10536  no_color
#
#                       vin        lot     state country    condition
# 502     wddjk7ea3hf044968  167607883   florida     usa  2 days left
# 1340    1ft8w4dt6ked32656  167780682  illinois     usa  2 days left

# %%
filter3 = (df['brand'].isin(['kia','hyundai']))&(df['price']>20000)

# %%
df[filter3]
# Out:
#      price brand    model  year   title_status  mileage color  \
# 26   21500   kia  sorento  2020  clean vehicle    11451  blue
# 631  21500   kia  sorento  2017  clean vehicle    43761  gray
#
#                      vin        lot           state country     condition
# 26     5xypg4a59lg616029  167801828  north carolina     usa   2 days left
# 631    5xypkda50hg299327  167119107     connecticut     usa  5 hours left

# %%
filter4 = (df['brand'].isin(['bmw']))&(df['price']>50000)&(df['color'].isin(['blue']))

# %%
df[filter4]
# Out:
#     price brand model  year   title_status  mileage color  \
# 95  53500   bmw     m  2017  clean vehicle    29355  blue
#
#                     vin        lot     state country    condition
# 95    5ymkt6c37h0x20696  167765095  michigan     usa  2 days left

# %%
filter5 = (df['brand'].isin(['bmw','kia','ford']))&(df['state'].isin(['connecticut','new york']))

# %%
df[filter5]
# Out:
#       price brand     model  year   title_status  mileage  \
# 176    7900  ford      door  2014  clean vehicle    79422
# 623   14000   kia   sorento  2017  clean vehicle    53424
# 626   13300   kia      door  2017  clean vehicle    37125
# 629   15500   kia   sorento  2017  clean vehicle    37668
# 631   21500   kia   sorento  2017  clean vehicle    43761
# 1201  28700  ford     doors  2015  clean vehicle    29733
# 1207  21289  ford     doors  2015  clean vehicle    71955
# 1604  18900  ford     doors  2015  clean vehicle    44456
# 1608  18288  ford     doors  2015  clean vehicle    45218
# 1775  20300  ford  explorer  2018  clean vehicle    19029
# 1776  26300  ford     f-150  2018  clean vehicle    11739
# 1781  12100  ford    escape  2017  clean vehicle    32284
# 1783   9500  ford    escape  2017  clean vehicle   107569
# 1786   7800  ford      door  2017  clean vehicle   108727
# 1787  17200  ford     f-150  2017  clean vehicle    91979
# ...

# %%
df[df.brand == 'chevrolet']
# Out:
#      price      brand     model  year   title_status  mileage   color  \
# 4    27700  chevrolet      1500  2018  clean vehicle     6654     red
# 6     7300  chevrolet        pk  2010  clean vehicle   149050   black
# 8    14600  chevrolet    malibu  2018  clean vehicle     9371  silver
# 12   31900  chevrolet      1500  2018  clean vehicle    22909   black
# 22   15000  chevrolet      door  2015  clean vehicle    61578   black
# ..     ...        ...       ...   ...            ...      ...     ...
# 803  28300  chevrolet        ld  2019  clean vehicle    27665     red
# 804  27300  chevrolet        ld  2019  clean vehicle    25427   black
# 805   3500  chevrolet      door  2013  clean vehicle    78198    gray
# 806  28300  chevrolet  colorado  2020  clean vehicle    13886  silver
# 807  18300  chevrolet    impala  2019  clean vehicle    34538  silver
#
#                      vin        lot       state country      condition
# ...

# %%
df.shape
# Out:
# (2499, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2499 entries, 0 to 2498
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         2499 non-null   int64
#  1   brand         2499 non-null   object
#  2   model         2499 non-null   object
#  3   year          2499 non-null   int64
#  4   title_status  2499 non-null   object
#  5   mileage       2499 non-null   int64
#  6   color         2499 non-null   object
#  7   vin           2499 non-null   object
#  8   lot           2499 non-null   int64
#  9   state         2499 non-null   object
#  10  country       2499 non-null   object
#  11  condition     2499 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 253.8+ KB

# %%
df.describe()
# Out:
#               price         year       mileage           lot
# count   2499.000000  2499.000000  2.499000e+03  2.499000e+03
# mean   18767.671469  2016.714286  5.229869e+04  1.676914e+08
# std    12116.094936     3.442656  5.970552e+04  2.038772e+05
# min        0.000000  1973.000000  0.000000e+00  1.593488e+08
# 25%    10200.000000  2016.000000  2.146650e+04  1.676253e+08
# 50%    16900.000000  2018.000000  3.536500e+04  1.677451e+08
# 75%    25555.500000  2019.000000  6.347250e+04  1.677798e+08
# max    84900.000000  2020.000000  1.017936e+06  1.678055e+08

# %%
df['price'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['year'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.columns
# Out:
# Index(['price', 'brand', 'model', 'year', 'title_status', 'mileage', 'color',
#        'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
df['mileage'].plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['price'].plot.line()
# Out:
# <Axes: >

# %%
df.plot.line(y='price',x='year')
# Out:
# <Axes: xlabel='year'>

# %%
df['price','year'].plot.line()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('price', 'year')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['price'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df['year'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df['mileage'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
>>> df = pd.DataFrame({
...    'pig': [20, 18, 489, 675, 1776],
...    'horse': [4, 25, 281, 600, 1900]
...    }, index=[1990, 1997, 2003, 2009, 2014])
>>> lines = df.plot.line()

# %%
df['price'].plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
ax1 = df.plot.scatter(x='price',
                      y='year',
                      c='DarkBlue')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# ...
