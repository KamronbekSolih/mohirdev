# %% [markdown]
# <a href="https://colab.research.google.com/github/KamronbekSolih/mohirdev/blob/main/DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Year':[2021,2020,2019,2018,2017,2016,2015],
    'Population':[33.9,33.5,32.9,32.5,31.9,31.5,30.9],
    'Temp':[1.54,1.48,1.56,1.43,1.34,1.57,1.64]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Year  Population  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.43
# 4  2017        31.9  1.34
# 5  2016        31.5  1.57
# 6  2015        30.9  1.64
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
# ...

# %%
df.head()
# Out:
#    Year  Population  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.43
# 4  2017        31.9  1.34

# %%
df.shape
# Out:
# (7, 3)

# %% [markdown]
# DataFrame columns

# %%
df = pd .DataFrame(data,columns=['Year','Temp','Population'])

# %%
df.head(3)
# Out:
#    Year  Temp  Population
# 0  2021  1.54        33.9
# 1  2020  1.48        33.5
# 2  2019  1.56        32.9

# %%
df = pd .DataFrame(data,columns=['Year','Temp','Population','GDP'])

# %%
df
# Out:
#    Year  Temp  Population  GDP
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN
# 3  2018  1.43        32.5  NaN
# 4  2017  1.34        31.9  NaN
# 5  2016  1.57        31.5  NaN
# 6  2015  1.64        30.9  NaN

# %%
df = pd .DataFrame(data,columns=['Population','GDP'],index=data['Year'])

# %%
df
# Out:
#       Population  GDP
# 2021        33.9  NaN
# 2020        33.5  NaN
# 2019        32.9  NaN
# 2018        32.5  NaN
# 2017        31.9  NaN
# 2016        31.5  NaN
# 2015        30.9  NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['Population'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
df['Population']
# Out:
# 2021    33.9
# 2020    33.5
# 2019    32.9
# 2018    32.5
# 2017    31.9
# 2016    31.5
# 2015    30.9
# Name: Population, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
population = df['Population']

# %%
population
# Out:
# 2021    33.9
# 2020    33.5
# 2019    32.9
# 2018    32.5
# 2017    31.9
# 2016    31.5
# 2015    30.9
# Name: Population, dtype: float64

# %%
type(population)
# Out:
# pandas.core.series.Series

# %%
df.Population
# Out:
# 2021    33.9
# 2020    33.5
# 2019    32.9
# 2018    32.5
# 2017    31.9
# 2016    31.5
# 2015    30.9
# Name: Population, dtype: float64

# %%
df.GDP
# Out:
# 2021    NaN
# 2020    NaN
# 2019    NaN
# 2018    NaN
# 2017    NaN
# 2016    NaN
# 2015    NaN
# Name: GDP, dtype: object

# %%
df.GDP = 0

# %%
df
# Out:
#       Population  GDP
# 2021        33.9    0
# 2020        33.5    0
# 2019        32.9    0
# 2018        32.5    0
# 2017        31.9    0
# 2016        31.5    0
# 2015        30.9    0

# %%
val = pd.Series([89,65,60,58], index=[np.arange(2017,2021)])

# %%
val
# Out:
# 2017    89
# 2018    65
# 2019    60
# 2020    58
# dtype: int64

# %%
df.GDP = pd.Series([89,65,60,58], index=np.arange(2017,2021,)[::-1])

# %%
df
# Out:
#       Population  GDP
# 2021        33.9    0
# 2020        33.5    0
# 2019        32.9    0
# 2018        32.5    0
# 2017        31.9    0
# 2016        31.5    0
# 2015        30.9    0

# %%
df['GDP'] = pd.Series([89,65,60,58], [2021,2020,2019,2018])

# %%
df
# Out:
#       Population   GDP
# 2021        33.9  89.0
# 2020        33.5  65.0
# 2019        32.9  60.0
# 2018        32.5  58.0
# 2017        31.9   NaN
# 2016        31.5   NaN
# 2015        30.9   NaN

# %%
gdps = np.random.uniform(50,90,7)
gdps = np.sort(gdps)[::-1]

# %%
df['GDP']  = gdps

# %%
df
# Out:
#       Population        GDP
# 2021        33.9  73.575144
# 2020        33.5  68.868925
# 2019        32.9  67.588148
# 2018        32.5  62.868420
# 2017        31.9  58.075579
# 2016        31.5  54.592980
# 2015        30.9  51.825807

# %%
df['Soar'] = df['GDP']>65

# %%
df
# Out:
#       Population        GDP   Soar
# 2021        33.9  73.575144   True
# 2020        33.5  68.868925   True
# 2019        32.9  67.588148   True
# 2018        32.5  62.868420  False
# 2017        31.9  58.075579  False
# 2016        31.5  54.592980  False
# 2015        30.9  51.825807  False

# %%
del df['Soar']

# %%
df
# Out:
#       Population        GDP
# 2021        33.9  73.575144
# 2020        33.5  68.868925
# 2019        32.9  67.588148
# 2018        32.5  62.868420
# 2017        31.9  58.075579
# 2016        31.5  54.592980
# 2015        30.9  51.825807
