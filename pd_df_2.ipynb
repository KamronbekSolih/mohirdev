# %% [markdown]
# <a href="https://colab.research.google.com/github/KamronbekSolih/mohirdev/blob/main/pd_df_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = {
    'Uzbekistan':{'2016':86.14,'2017':62.08,'2018':52.87, '2019':60.28,'2020':60.22,'2021':69.6,'2022':80.39},
    'Kazakhistan':{'2016':137.28,'2017':166.81,'2018':179.34, '2019':181.67,'2020':171.08,'2021':197.11,'2022':220.62}

}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Uzbekistan  Kazakhistan
# 2016       86.14       137.28
# 2017       62.08       166.81
# 2018       52.87       179.34
# 2019       60.28       181.67
# 2020       60.22       171.08
# 2021       69.60       197.11
# 2022       80.39       220.62
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df, *['Uzbekistan'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
# ...

# %%
df.index.name = 'Year'

# %%
df
# Out:
#       Uzbekistan  Kazakhistan
# Year
# 2016       86.14       137.28
# 2017       62.08       166.81
# 2018       52.87       179.34
# 2019       60.28       181.67
# 2020       60.22       171.08
# 2021       69.60       197.11
# 2022       80.39       220.62

# %%
df = pd.DataFrame(data,index=[2022,2016])

# %%
df
# Out:
#       Uzbekistan  Kazakhistan
# 2022         NaN          NaN
# 2016         NaN          NaN

# %%
df.T
# Out:
#              2022  2016
# Uzbekistan    NaN   NaN
# Kazakhistan   NaN   NaN

# %%
df.values
# Out:
# array([[nan, nan],
#        [nan, nan]])

# %% [markdown]
# Index

# %%
usernames = {"anvar":"anvarbek223", "olim":"olimtoy", "maryam":"mary334455","javohir":"javohir445"}
emails = {"anvar":"anvar@gmail.com", "olim":"olim@mail.ru", "maryam":"mary33@gmail.com","javohir":"javohir445@gmail.com"}

data = {
    'username':usernames,
    'email':emails
}
df = pd.DataFrame(data)

# %%
df
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com

# %%
data2 = {
    'username':{"olim":"olimjon21", "maryam":"maryam2020"},
    'email':{"olim":"olimjon21@mail.ru", "maryam":"maryam20@gmail.com"}
}

# %%
df2 = df.append(pd.DataFrame(data2))
# Out:
# <ipython-input-7-320d686ce405>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df.append(pd.DataFrame(data2))

# %%
df2
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %%
df2.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
newind = pd.Index(['olim','nafisa','hamida'])

# %%
newind
# Out:
# Index(['olim', 'nafisa', 'hamida'], dtype='object')

# %%
newind.isin(df2.index)
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newind)
# Out:
# Index(['anvar', 'javohir', 'maryam'], dtype='object')

# %%
newind.difference(df2.index)
# Out:
# Index(['hamida', 'nafisa'], dtype='object')

# %%
df2.index.union(newind)
# Out:
# Index(['anvar', 'hamida', 'javohir', 'maryam', 'maryam', 'nafisa', 'olim',
#        'olim'],
#       dtype='object')

# %%
df2
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %%
df2.index.delete(0)
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
df2.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim', 'maryam'], dtype='object')

# %%
df2.index.drop('olim')
# Out:
# Index(['anvar', 'maryam', 'javohir', 'maryam'], dtype='object')

# %%
df2
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21     olimjon21@mail.ru
# maryam    maryam2020    maryam20@gmail.com

# %%
a = df2.index.insert(5,'masha')

# %%
a
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim', 'masha', 'maryam'], dtype='object')

# %%
df2.index.is_monotonic
# Out:
# <ipython-input-36-bfe5a8da6fb5>:1: FutureWarning: is_monotonic is deprecated and will be removed in a future version. Use is_monotonic_increasing instead.
#   df2.index.is_monotonic
# False

# %%
df2.is_monotonic_increasing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-5f96002ba3b5> in <cell line: 1>()
# ----> 1 df2.is_monotonic_increasing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'is_monotonic_increasing'

# %%
df2.index.is_unique
# Out:
# False

# %%
df2.index.unique()
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')
